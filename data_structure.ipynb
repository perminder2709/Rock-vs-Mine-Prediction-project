# %%
#Write a code to reverse a string?
#def reverse_string(s):
    return s[::-1]

# Example usage
string = "Hello, World!"
reversed_string = reverse_string(string)
print(f"Original String: {string}")
print(f"Reversed String: {reversed_string}")

# %%
#Write a code to count the number of vowels in a string?
#def count_vowels(s):
    vowels = "aeiouAEIOU"  # List of vowels (both uppercase and lowercase)
    count = sum(1 for char in s if char in vowels)
    return count

# Example usage
string = "Hello, World!"
vowel_count = count_vowels(string)
print(f"Number of vowels in '{string}': {vowel_count}")

# %%
#Write a code to check if a given string is a palindrome or not?
#def is_palindrome(s):
    # Remove non-alphanumeric characters and convert to lowercase
    cleaned_string = ''.join(char.lower() for char in s if char.isalnum())
    # Check if the cleaned string is the same when reversed
    return cleaned_string == cleaned_string[::-1]

# Example usage
string = "A man, a plan, a canal, Panama"
if is_palindrome(string):
    print(f"'{string}' is a palindrome.")
else:
    print(f"'{string}' is not a palindrome.")

# %%
#Write a code to check if two given strings are anagrams of each other
#def are_anagrams(str1, str2):
    # Remove whitespace and convert to lowercase
    str1_cleaned = ''.join(sorted(str1.replace(" ", "").lower()))
    str2_cleaned = ''.join(sorted(str2.replace(" ", "").lower()))
    # Compare the sorted versions of both strings
    return str1_cleaned == str2_cleaned

# Example usage
string1 = "Listen"
string2 = "Silent"
if are_anagrams(string1, string2):
    print(f"'{string1}' and '{string2}' are anagrams.")
else:
    print(f"'{string1}' and '{string2}' are not anagrams.")

# %%
# Write a code to find all occurrences of a given substring within another string?
#def find_substring_occurrences(text, substring):
    occurrences = []
    start = 0
    while start < len(text):
        # Find the next occurrence of the substring
        start = text.find(substring, start)
        if start == -1:  # No more occurrences
            break
        occurrences.append(start)
        start += 1  # Move past the last found occurrence
    return occurrences

# Example usage
text = "This is a test. Testing is fun. Test this!"
substring = "test"
positions = find_substring_occurrences(text.lower(), substring.lower())
print(f"Occurrences of '{substring}': {positions}")

# %%
#Write a code to perform basic string compression using the counts of repeated characters
#def compress_string(s):
    compressed = []
    count = 1

    for i in range(1, len(s)):
        if s[i] == s[i - 1]:  # Check if the current character is the same as the previous one
            count += 1
        else:
            compressed.append(s[i - 1] + str(count))  # Append the character and its count
            count = 1

    # Add the last character and its count
    if s:
        compressed.append(s[-1] + str(count))

    # Join the compressed parts and return the shorter of the original and compressed strings
    compressed_string = ''.join(compressed)
    return compressed_string if len(compressed_string) < len(s) else s

# Example usage
string = "aabcccccaaa"
compressed = compress_string(string)
print(f"Original: {string}")
print(f"Compressed: {compressed}")

# %%
#Write a code to determine if a string has all unique characters?
#def has_unique_characters(s):
    # Use a set to store seen characters
    seen = set()
    for char in s:
        if char in seen:
            return False
        seen.add(char)
    return True

# Example usage
string = "abcdefg"
if has_unique_characters(string):
    print(f"The string '{string}' has all unique characters.")
else:
    print(f"The string '{string}' does not have all unique characters.")

# %%
#Write a code to convert a given string to uppercase or lowercase?
#def convert_case(s, to_upper=True):
    if to_upper:
        return s.upper()  # Convert to uppercase
    else:
        return s.lower()  # Convert to lowercase

# Example usage
string = "Hello, World!"
uppercase_string = convert_case(string, to_upper=True)
lowercase_string = convert_case(string, to_upper=False)

print(f"Original: {string}")
print(f"Uppercase: {uppercase_string}")
print(f"Lowercase: {lowercase_string}")

# %%
#Write a code to count the number of words in a string?
#def count_words(s):
    # Split the string by whitespace and count the resulting words
    words = s.split()
    return len(words)

# Example usage
string = "Hello, how are you doing today?"
word_count = count_words(string)

print(f"The string '{string}' contains {word_count} words.")

# %%
# Write a code to concatenate two strings without using the + operator?
#def concatenate_strings(s1, s2):
    return "".join([s1, s2])  # Use join method to concatenate

# Example usage
string1 = "Hello"
string2 = "World"
result = concatenate_strings(string1, string2)

print(f"Concatenated String: {result}")

# %%
#Write a code to remove all occurrences of a specific element from a list?
#def remove_element(lst, element):
    return [x for x in lst if x != element]

# Example usage
original_list = [1, 2, 3, 4, 2, 5, 2]
element_to_remove = 2
updated_list = remove_element(original_list, element_to_remove)

print(f"Original List: {original_list}")
print(f"Updated List: {updated_list}")

# %%
#Implement a code to find the second largest number in a given list of integers?
#def find_second_largest(nums):
    if len(nums) < 2:
        return None  # Not enough elements to determine second largest

    first, second = float('-inf'), float('-inf')
    
    for num in nums:
        if num > first:
            # Update both first and second largest
            second = first
            first = num
        elif num > second and num != first:
            # Update second largest only
            second = num

    return second if second != float('-inf') else None

# Example usage
numbers = [10, 20, 4, 45, 99, 99]
second_largest = find_second_largest(numbers)

if second_largest is not None:
    print(f"The second largest number is {second_largest}.")
else:
    print("The list doesn't have enough unique elements to determine the second largest number.")

# %%
#Create a code to count the occurrences of each element in a list and return a dictionary with elements as keys and their counts as values
#def count_occurrences(lst):
    occurrences = {}
    for item in lst:
        occurrences[item] = occurrences.get(item, 0) + 1
    return occurrences

# Example usage
elements = [1, 2, 3, 2, 4, 1, 1, 2, 5]
result = count_occurrences(elements)

print(f"Occurrences: {result}")

# %%
# Write a code to reverse a list in-place without using any built-in reverse functions?
#def reverse_list(lst):
    left, right = 0, len(lst) - 1
    while left < right:
        # Swap the elements at the left and right indices
        lst[left], lst[right] = lst[right], lst[left]
        # Move the pointers closer to the center
        left += 1
        right -= 1

# Example usage
numbers = [1, 2, 3, 4, 5]
reverse_list(numbers)
print(f"Reversed List: {numbers}")

# %%
#Implement a code to find and remove duplicates from a list while preserving the original order of elements?
#def remove_duplicates(lst):
    seen = set()
    result = []
    for item in lst:
        if item not in seen:
            seen.add(item)
            result.append(item)
    return result

# Example usage
original_list = [1, 2, 2, 3, 4, 3, 5, 1]
deduplicated_list = remove_duplicates(original_list)

print(f"Original List: {original_list}")
print(f"List after removing duplicates: {deduplicated_list}")

# %%
#Create a code to check if a given list is sorted (either in ascending or descending order) or not?
#def is_sorted(lst):
    if all(lst[i] <= lst[i + 1] for i in range(len(lst) - 1)):
        return "Ascending"
    elif all(lst[i] >= lst[i + 1] for i in range(len(lst) - 1)):
        return "Descending"
    else:
        return "Not sorted"

# Example usage
test_list1 = [1, 2, 3, 4, 5]
test_list2 = [5, 4, 3, 2, 1]
test_list3 = [1, 3, 2, 4, 5]

print(f"Test List 1: {is_sorted(test_list1)}")
print(f"Test List 2: {is_sorted(test_list2)}")
print(f"Test List 3: {is_sorted(test_list3)}")

# %%
#Write a code to merge two sorted lists into a single sorted list?
#def merge_sorted_lists(list1, list2):
    merged_list = []
    i, j = 0, 0

    # Merge the lists by comparing elements
    while i < len(list1) and j < len(list2):
        if list1[i] <= list2[j]:
            merged_list.append(list1[i])
            i += 1
        else:
            merged_list.append(list2[j])
            j += 1

    # Add any remaining elements from list1 or list2
    merged_list.extend(list1[i:])
    merged_list.extend(list2[j:])

    return merged_list

# Example usage
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]
merged = merge_sorted_lists(list1, list2)

print(f"List 1: {list1}")
print(f"List 2: {list2}")
print(f"Merged List: {merged}")

# %%
# Implement a code to find the intersection of two given lists?
#def find_intersection(list1, list2):
    # Use a set for efficient lookups
    set1 = set(list1)
    set2 = set(list2)
    return list(set1 & set2)  # Return the intersection as a list

# Example usage
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
intersection = find_intersection(list1, list2)

print(f"List 1: {list1}")
print(f"List 2: {list2}")
print(f"Intersection: {intersection}")

# %%
#Create a code to find the union of two lists without duplicates?
#def union_lists(list1, list2):
    # Convert both lists to sets and perform union
    union_set = set(list1) | set(list2)
    return list(union_set)

# Example usage
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5, 6]
union = union_lists(list1, list2)

print(f"List 1: {list1}")
print(f"List 2: {list2}")
print(f"Union without duplicates: {union}")

# %%
#Write a code to shuffle a given list randomly without using any built-in shuffle functions?
#import random

def custom_shuffle(lst):
    n = len(lst)
    for i in range(n - 1, 0, -1):
        # Pick a random index from 0 to i
        j = random.randint(0, i)
        # Swap elements at indices i and j
        lst[i], lst[j] = lst[j], lst[i]

# Example usage
my_list = [1, 2, 3, 4, 5]
custom_shuffle(my_list)
print(f"Shuffled list: {my_list}")

# %%
#Write a code that takes two tuples as input and returns a new tuple containing elements that are common to both input tuples?
#def common_elements(tuple1, tuple2):
    # Convert tuples to sets and find intersection
    common = set(tuple1) & set(tuple2)
    # Convert the set back to a tuple
    return tuple(common)

# Example usage
t1 = (1, 2, 3, 4, 5)
t2 = (3, 4, 5, 6, 7)
result = common_elements(t1, t2)

print(f"Tuple 1: {t1}")
print(f"Tuple 2: {t2}")
print(f"Common elements: {result}")

# %%
# Create a code that prompts the user to enter two sets of integers separated by commas. Then, print the intersection of these two sets?
#def get_set_from_input(prompt):
    user_input = input(prompt)
    # Split input by commas, strip spaces, convert to integers, and make a set
    return set(int(x.strip()) for x in user_input.split(',') if x.strip().isdigit())

# Get two sets from user
set1 = get_set_from_input("Enter the first set of integers, separated by commas: ")
set2 = get_set_from_input("Enter the second set of integers, separated by commas: ")

# Find intersection
intersection = set1 & set2

print(f"Intersection of the two sets: {intersection}")

# %%
#Write a code to concatenate two tuples. The function should take two tuples as input and return a new tuple containing elements from both input tuples?
#def concatenate_tuples(t1, t2):
    return t1 + t2

# Example usage
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
result = concatenate_tuples(tuple1, tuple2)

print(f"Tuple 1: {tuple1}")
print(f"Tuple 2: {tuple2}")
print(f"Concatenated Tuple: {result}")

# %%
# Develop a code that prompts the user to input two sets of strings. Then, print the elements that are present in the first set but not in the second set?
#def get_string_set(prompt):
    user_input = input(prompt)
    # Split input by commas and strip whitespace
    return set(s.strip() for s in user_input.split(',') if s.strip())

# Get two sets of strings from user
set1 = get_string_set("Enter the first set of strings, separated by commas: ")
set2 = get_string_set("Enter the second set of strings, separated by commas: ")

# Find difference (elements in set1 but not in set2)
difference = set1 - set2

print(f"Elements in the first set but not in the second set: {difference}")

# %%
#Create a code that takes a tuple and two integers as input. The function should return a new tuple containing elements from the original tuple within the specified range of indices?
#def slice_tuple(tpl, start, end):
    # Slice the tuple from start to end (end index is exclusive)
    return tpl[start:end]

# Example usage
original_tuple = (10, 20, 30, 40, 50, 60)
start_index = 2
end_index = 5

result = slice_tuple(original_tuple, start_index, end_index)
print(f"Original tuple: {original_tuple}")
print(f"Sliced tuple (from index {start_index} to {end_index}): {result}")

# %%
#Write a code that prompts the user to input two sets of characters. Then, print the union of these two sets?
#def get_char_set(prompt):
    user_input = input(prompt)
    # Remove spaces and convert to set of characters
    return set(user_input.replace(" ", ""))

# Get two sets of characters from user
set1 = get_char_set("Enter the first set of characters (e.g. a,b,c): ")
set2 = get_char_set("Enter the second set of characters (e.g. x,y,z): ")

# Find union
union_set = set1 | set2

print(f"Union of the two sets: {union_set}")

# %%
#Develop a code that prompts the user to input two sets of strings. Then, print the symmetric difference of these two sets?
#def get_string_set(prompt):
    user_input = input(prompt)
    # Split input by commas, strip whitespace, and create a set
    return set(s.strip() for s in user_input.split(',') if s.strip())

# Get two sets of strings from user
set1 = get_string_set("Enter the first set of strings, separated by commas: ")
set2 = get_string_set("Enter the second set of strings, separated by commas: ")

# Find symmetric difference
sym_diff = set1 ^ set2  # or set1.symmetric_difference(set2)

print(f"Symmetric difference of the two sets: {sym_diff}")
